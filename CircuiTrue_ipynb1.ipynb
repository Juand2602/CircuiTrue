# %% [markdown]
# <a href="https://colab.research.google.com/github/Juand2602/CircuiTrue/blob/main/CircuiTrue_ipynb1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instructivo de cómo usar CircuiTrue:
# 1.	El usuario deberá dirigirse a la clase circuitrue, e ingresar en la función tantos 0 como tantas variables desee tener.
#
# 2.	Seguido deberá inicializar las variables en la funcion def entradas siguiendo el formato ejemplo: “variable.p = p”, esto se hace dependiendo de las veces que inicializó la variable en el paso anterior, por ejemplo si inicializó cinco ceros deberá hacerlo cinco veces.
#
# 3.	En la clase sentencia dependiendo de lo que el usuario desea calcular la operación and u or si desea calcular el and entre dos entradas (p and q) deberá colocar “variable.s = variable.p and variable.q” podrá mezclar entre las variables como desee, igualmente para la sentencia or cambiando el operador lógico correspondiente
#
# 4.	En la tabla de verdad podrá crear su tabla siguiendo el formato ejemplo y los corchetes {} dependerán de las veces que realice una operación.

# %% [markdown]
# A continuación encontrará el programa que resuelve circuitos lógicos con n entradas. Para crear el circuito lógico primero digite cuántas entradas desea que tenga este circuito lógico.
#
# Tenga en cuenta que únicamente puede hacer uso de los siguientes símbolos lógicos para diseñar su sitencia:  $¬$ $∧$ $∨$.
#
# Para visualizar su circuito lógico y crear su sentencia guíese de la siguiente imagen.![circuito.png](data:image/png;base64,...)
#
# Como podrá ver este circuito diseñado de esta manera puede ser escrito en una sentencia lógia de la siguiente manera:
#
# $ (¬ 𝚙 ∧ ¬ 𝚚) ∨ (𝚙 ∧ 𝚛) $

# %%
class CircuiTrue:

  def iniVariables(variable):
    variable.entradas(0,0,0,0) # Por favor coloque ceros como tantas variables desee tener
  
  def entradas(variable,p,q,r,t): # Inicialice sus variables siguiendo el siguiente formarto: variable."Aquí ponga el nombre de su variable" = variable.
    variable.p = p              # Es estrictamente necesario que inicialice todas las variables que definió en inivariables es decir que sí coloco 5 ceros
    variable.q = q              # Inicialice 5 variables
    variable.r = r
    variable.t = t
    variable.calcular()
  
  def calcular(variable): #Truco para una función que no queremos implementar
    pass
  
  def salida(variable):
    return variable.s

# %%
class sentenciaAnd(CircuiTrue):                  # Para calcular todas las salidas and siga el formato:
  def calcular(variable):                        # variable.s = variable."Primera variable" and variable."Segunda variable"
    variable.s = variable.p and variable.q       # Realice este procedimiento tantas veces halla definido las variables
    variable.s = variable.q and variable.r
    variable.s = variable.p and variable.r
    variable.s = variable.t and variable.p
    variable.s = variable.t and variable.q
    variable.s = variable.t and variable.r

# %%
class SentenciaOr(CircuiTrue):                    # Para calcular todas las salidas or siga el formato:
  def calcular(variable):                         # variable.s = variable."Primera variable" or variable."Segunda variable"
    variable.s = variable.p or variable.q         # variable.s = variable."Primera variable" or variable."Tercera variable" y así sucesivamente
    variable.s = variable.q or variable.r         # Realice este procedimiento tantas veces halla definido las variables
    variable.s = variable.p or variable.r
    variable.s = variable.t or variable.p
    variable.s = variable.t or variable.q
    variable.s = variable.t or variable.r

# %%
class TabladeVerdad:
  def tabladeverdad(variable):

    print("Dos variables")
    print("En el siguiente circuito establecer para qué valores de verdad de las variables p, q la salida es verdadera (T).")
    print("p q     p ∧ q      p ∨ q      (¬p ∧ ¬p) ∨ (p ∧ q)")

    print("{} {}     {}      {}      {}".format(0, 0, bool(0 and 0), bool(0 or 0), bool(((not 0) and (not 0)) or (0 and 0))))
    print("{} {}     {}      {}      {}".format(0, 1, bool(0 and 1), bool(0 or 1), bool(((not 0) and (not 1)) or (0 and 1))))
    print("{} {}     {}      {}      {}".format(1, 0, bool(1 and 0), bool(1 or 0), bool(((not 1) and (not 0)) or (1 and 0))))
    print("{} {}     {}      {}      {}".format(1, 1, bool(1 and 1), bool(1 or 1), bool(((not 1) and (not 1)) or (1 and 1))))

    print("Tres variables")
    print("En el siguiente circuito establecer para qué valores de verdad de las variables p, q, r la salida es verdadera (T).")
    print("p q r   ¬p     ¬q      ¬p ∧ ¬q         p ∧ r   (¬p ∧ ¬q)  ∨ (p ∧ r) ")
    print("{} {} {}  {}  {}     {}          {}              {}".format(1, 1, 1, (not 1), (not 1), (not 1) and (not 1), bool(1 and 1), (((not 1) and (not 1)) or bool(1 and 1))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(1, 1, 0, (not 1), (not 1), (not 1) and (not 1), bool(1 and 0), (((not 1) and (not 1)) or bool(1 and 0))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(1, 0, 0, (not 1), (not 0), (not 1) and (not 0), bool(1 and 0), (((not 1) and (not 0)) or bool(1 and 0))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(1, 0, 1, (not 1), (not 0), (not 1) and (not 0), bool(1 and 1), (((not 1) and (not 0)) or bool(1 and 1))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(0, 1, 0, (not 0), (not 1), (not 0) and (not 1), bool(0 and 0), (((not 0) and (not 1)) or bool(0 and 0))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(0, 1, 1, (not 0), (not 1), (not 0) and (not 1), bool(0 and 1), (((not 0) and (not 1)) or bool(0 and 1))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(0, 0, 1, (not 0), (not 0), (not 0) and (not 0), bool(0 and 1), (((not 0) and (not 0)) or bool(0 and 1))))
    print("{} {} {}  {}  {}     {}          {}              {}".format(0, 0, 0, (not 0), (not 0), (not 0) and (not 0), bool(0 and 0), (((not 0) and (not 0)) or bool(0 and 0))))

    print("Cuatro variables")
    print("En el siguiente circuito establecer para qué valores de verdad de las variables p, q, r, s la salida es verdadera (T).")
    print("p q r t   ¬p     ¬r      ¬p ∧ ¬r         p ∧ t   (¬p ∧ ¬r)  ∨ (q ∧ t) ")
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 1, 1, 1, (not 1), (not 1), (not 1) and (not 1), bool(1 and 1), (((not 1) and (not 1)) or bool(1 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 1, 1, 0, (not 1), (not 1), (not 1) and (not 1), bool(1 and 0), (((not 1) and (not 1)) or bool(1 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 1, 0, 1, (not 1), (not 0), (not 1) and (not 0), bool(1 and 1), (((not 1) and (not 0)) or bool(1 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 1, 0, 0, (not 1), (not 0), (not 1) and (not 0), bool(1 and 0), (((not 1) and (not 0)) or bool(1 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 0, 1, 1, (not 0), (not 1), (not 0) and (not 1), bool(0 and 1), (((not 0) and (not 1)) or bool(0 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 0, 1, 0, (not 0), (not 1), (not 0) and (not 1), bool(0 and 0), (((not 0) and (not 1)) or bool(0 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 0, 0, 1, (not 0), (not 0), (not 0) and (not 0), bool(0 and 1), (((not 0) and (not 0)) or bool(0 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(1, 0, 0, 0, (not 0), (not 0), (not 0) and (not 0), bool(0 and 0), (((not 0) and (not 0)) or bool(0 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 1, 1, 1, (not 0), (not 1), (not 0) and (not 1), bool(1 and 1), (((not 0) and (not 1)) or bool(1 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 1, 1, 0, (not 0), (not 1), (not 0) and (not 1), bool(1 and 0), (((not 0) and (not 1)) or bool(1 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 1, 0, 1, (not 0), (not 0), (not 0) and (not 0), bool(1 and 1), (((not 0) and (not 0)) or bool(1 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 1, 0, 0, (not 0), (not 0), (not 0) and (not 0), bool(1 and 0), (((not 0) and (not 0)) or bool(1 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 0, 1, 1, (not 0), (not 1), (not 0) and (not 1), bool(0 and 1), (((not 0) and (not 1)) or bool(0 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 0, 1, 0, (not 0), (not 1), (not 0) and (not 1), bool(0 and 0), (((not 0) and (not 1)) or bool(0 and 0))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 0, 0, 1, (not 0), (not 0), (not 0) and (not 0), bool(0 and 1), (((not 0) and (not 0)) or bool(0 and 1))))
    print("{} {} {} {}  {}  {}     {}          {}              {}".format(0, 0, 0, 0, (not 0), (not 0), (not 0) and (not 0), bool(0 and 0), (((not 0) and (not 0)) or bool(0 and 0))))

# %%
x = TabladeVerdad()
x.tabladeverdad()
# Out:
# Dos variables
# En el siguiente circuito establecer para qué valores de verdad de las variables p, q la salida es verdadera (T).
# p q     p ∧ q      p ∨ q      (¬p ∧ ¬p) ∨ (p ∧ q)
# 0 0     False      False      True
# 0 1     False      True      False
# 1 0     False      True      False
# 1 1     True      True      True
# Tres variables
# En el siguiente circuito establecer para qué valores de verdad de las variables p, q, r la salida es verdadera (T).
# p q r   ¬p     ¬q      ¬p ∧ ¬q         p ∧ r   (¬p ∧ ¬q)  ∨ (p ∧ r)
# 1 1 1  False  False     False          True              True
# 1 1 0  False  False     False          False              False
# 1 0 0  False  True     False          False              False
# 1 0 1  False  True     False          True              True
# 0 1 0  True  False     False          False              False
# 0 1 1  True  False     False          False              False
# 0 0 1  True  True     True          False              True
# ...

# %% [markdown]
# ## Tabla de verdad para el circuito lógico de tres variables definido anteriormente.
# ![image.png](data:image/png;base64,...)
